# %%
import numpy as np
import librosa
import numpy as np
import pandas as pd
from IPython.display import Audio
import matplotlib.pyplot as plt

# %% [markdown]
# ### A1. Find the first derivative of your speech signal with finite difference method. Listen to the first derivative signal and the original speech signal.

# %%
y, sr = librosa.load(r"C:\Users\pothi\Downloads\speech audio.wav")

# Compute the first derivative using finite difference method
first_derivative = np.diff(y)
# Plot the original speech signal
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(np.arange(len(y)) / sr, y)
plt.title('Original Speech Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

# Plot the first derivative
plt.subplot(2, 1, 2)
plt.plot(np.arange(len(first_derivative)) / sr, first_derivative)
plt.title('First Derivative')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.tight_layout()
plt.show()

# Convert arrays to audio objects and listen
original_audio = Audio(y, rate=sr)
derivative_audio = Audio(first_derivative, rate=sr)

print("Original Speech Signal:")
display(original_audio)
print("First Derivative:")
display(derivative_audio)
# Out:
# Original Speech Signal:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# First Derivative:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### A2. Detect the points of zero crossing in the first derivative signal. Compare the average length between two consecutive zero crossings for speech and silence regions. Observe the pattern.

# %%
# Calculate the first derivative of the signal
y_diff = np.diff(y)

# Detect the points of zero crossing
zero_crossings = librosa.zero_crossings(y_diff, pad=False)

# Calculate the average length between two consecutive zero crossings for speech and silence regions
speech_regions = np.where(y != 0)[0]
silence_regions = np.where(y == 0)[0]

avg_length_speech = np.mean(np.diff(speech_regions))
avg_length_silence = np.mean(np.diff(silence_regions))

print(f'Average length between two consecutive zero crossings for speech regions: {avg_length_speech}')
print(f'Average length between two consecutive zero crossings for silence regions: {avg_length_silence}')

import matplotlib.pyplot as plt

# Plot the zero-crossings
plt.figure(figsize=(16, 6))
plt.plot(zero_crossings)
plt.title('Zero-crossings')
plt.show()

# Plot the speech and silence regions
plt.figure(figsize=(16, 6))
plt.plot(y)
plt.scatter(speech_regions, y[speech_regions], color='b', label='Speech')
plt.scatter(silence_regions, y[silence_regions], color='r', label='Silence')
plt.legend()
plt.title('Speech and Silence Regions')
plt.show()
# Out:
# Average length between two consecutive zero crossings for speech regions: 1.0
# Average length between two consecutive zero crossings for silence regions: 1.0

# %% [markdown]
# ### 3. Speak 5 of your favorite words. Observe the length of the speech signals. Compare the lengths of your spoken words with those of your project team-mate.

# %%
import librosa

# Load the first audio file
y1, sr1 = librosa.load(r"C:\Users\pothi\Downloads\SPeech processing 2 audio.wav")

# Calculate the length of the first audio file
length1 = len(y1) / sr1
print(f'Length of Recording.wav: {length1} seconds')

# Load the second audio file
y2, sr2 = librosa.load(r"C:\Users\pothi\Downloads\Mokshith voice.wav")

# Calculate the length of the second audio file
length2 = len(y2) / sr2
print(f'Length of Record2.wav: {length2} seconds')
# Out:
# Length of Recording.wav: 3.1786848072562357 seconds
# C:\Users\pothi\AppData\Local\Temp\ipykernel_16524\2055314715.py:11: UserWarning: PySoundFile failed. Trying audioread instead.
#   y2, sr2 = librosa.load('Record2.wav')
# D:\Anaconda\lib\site-packages\librosa\core\audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\librosa\core\audio.py:175, in load(path, sr, mono, offset, duration, dtype, res_type)
#     174 try:
# --> 175     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     177 except sf.SoundFileRuntimeError as exc:
#     178     # If soundfile failed, try audioread instead
#
# ...

# %% [markdown]
# ### A4 Select a sentence which can be used for making a statement or asking a question. Ex: “You are going to college on Sunday(./?)”. Record two signals – one with making the statement while other with asking question. Study the two signals and compare them

# %%
y_statement, sr_statement = librosa.load(r"C:\Users\pothi\Downloads\answer.wav")
y_question, sr_question = librosa.load(r"C:\Users\pothi\Downloads\question.wav")


time_statement = librosa.times_like(y_statement, sr=sr_statement)
time_question = librosa.times_like(y_question, sr=sr_question)


plt.figure(figsize=(16, 6))
plt.plot(time_statement, y_statement)
plt.title('Waveform of the Statement')
plt.show()


plt.figure(figsize=(16, 6))
plt.plot(time_question, y_question)
plt.title('Waveform of the Question')
plt.show()
