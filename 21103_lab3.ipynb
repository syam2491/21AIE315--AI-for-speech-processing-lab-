# %% [markdown]
# # Q1. Use librosa.effects.trim() to remove the silence parts of speech from beginning and end of your recorded signal. Listen to the new signal and perceptually compare the audio with original.

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

y, sr = librosa.load("/content/drive/MyDrive/AI_SP/AI_SP_audio.wav")
librosa.display.waveshow(y)
plt.title('Original Speech Signal')
# Out:
# Text(0.5, 1.0, 'Original Speech Signal')

# %%
z, index = librosa.effects.trim(y)
librosa.display.waveshow(z)
plt.title('Trimmed Speech Signal')
# Out:
# Text(0.5, 1.0, 'Trimmed Speech Signal')

# %%
import IPython.display as ipd

print("Trimmed Audio")
ipd.Audio(data=z, rate=sr)
# Out:
# Trimmed Audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Original Audio")
ipd.Audio(data=y, rate=sr)
# Out:
# Original Audio
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Q2. Use librosa.effects.split() to split the recorded speech with detected silences. Play around with the top_db parameter and see the effects of split. Listen to the generated signals and observe the split quality.

# %%
w = librosa.effects.split(y, top_db=30)
for i, segment in enumerate(w):
    start, end = segment
    segment_audio = y[start:end]
    print(f"Segment {i+1}: Duration {len(segment_audio)/sr} seconds")
# Out:
# Segment 1: Duration 0.25541950113378686 seconds
# Segment 2: Duration 0.11609977324263039 seconds
# Segment 3: Duration 0.09287981859410431 seconds
# Segment 4: Duration 0.5804988662131519 seconds
# Segment 5: Duration 0.3250793650793651 seconds
# Segment 6: Duration 0.37151927437641724 seconds
# Segment 7: Duration 0.5804988662131519 seconds
# Segment 8: Duration 0.2089795918367347 seconds
